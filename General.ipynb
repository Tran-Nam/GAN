# %% [markdown]
# # DCGAN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # WGAN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # WGAN-GP

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Các trường hợp khi train WGAN

# %% [markdown]
# ![image.png](attachment:image.png)
# c = 0.1

# %% [markdown]
# ![image.png](attachment:image.png)
# c = 0.01

# %% [markdown]
# Khi c quá bé, mô hình sẽ không học được
